# %% [markdown]
# ###Goal of the project is to:
#
# 1-- Do simple Data Analysis
# ----Duel with missing values
# ---Format the date or test
#
# 2---Enchance Phyton Concepts
#
# 3-----Explore more 3rd party libraries ----Report Lab

# %%
#install external package "reportlab" because it is not in normal phyton

#Overview the steps
#1-Download/Import Packages
#2-Reading and explore datasheet
#3-Data Cleaning(Data Analysis)


# !pip install reportlab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 9.1 MB/s eta 0:00:00
# ...

# %%
#Mount google drive(connect this project with folder we upload)

from google.colab import drive

# %%
import pandas as pd
import numpy as np
from reportlab.lib.pagesizes import landscape, A4
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont

# %% [markdown]
# 2. Reading and Exploring the excel file

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Certificate Generator/dataset.xlsx')
df
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 4                    -                    NaN      Advanced        NaT
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 8      Jonathan Bucker                    NaN           NaN        NaT
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         13 non-null     object
#  1   Course       11 non-null     object
#  2   CourseLevel  12 non-null     object
#  3   Date         11 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 544.0+ bytes

# %% [markdown]
# #3----Data Cleaning (Data Analysis)
#
# Data Cleaning------Formattiong the data before certificate generator logic
#
# --deal with missing value
# --format the data or text

# %%
###the problem with the original datasheet(raw excel file)

#1---inconsistency with format
#2---Date format(yyyy/mm//dd)----------format (dd/mm/yyyy)
#3---Empty row

# %%
df=df.dropna()#drop null value

df

#fyi ,in real world we dont neccessliry remove whole row that contain empty value
#imputation------------>fill it with other value
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  AI & Machine Learning      Beginner 2023-09-20

# %%
#Problem 2 : Date Format
df['Date']
# Out:
# 0    2023-09-10
# 1    2023-09-11
# 2    2023-09-12
# 3    2023-09-13
# 5    2023-09-14
# 6    2023-09-15
# 7    2023-09-16
# 9    2023-09-17
# 10   2023-09-18
# 11   2023-09-19
# 12   2023-09-20
# Name: Date, dtype: datetime64[ns]

# %%
df['Date'].iloc[0]
# Out:
# Timestamp('2023-09-10 00:00:00')

# %%
#create new column called Formatted Date and create new data format
#Remove Date column


df['Formatted Date']=df['Date'].dt.strftime('%d/%m/%Y')
df


#strftime-----------convert Timestamp object into string representation(follow specific format)
# Out:
# <ipython-input-38-8f4e44658e47>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Formatted Date']=df['Date'].dt.strftime('%d/%m/%Y')
#                   Name                 Course   CourseLevel       Date  \
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# ...

# %%
#remove the date column for next step
df=df.drop('Date',axis=1)#axis 0---remove all row , axis =1 remove all column
df
# Out:
#                   Name                 Course   CourseLevel Formatted Date
# 0   Christy Cunningham                 Python      Beginner     10/09/2023
# 1       Douglas Tucker                 PYTHON       MASTER      11/09/2023
# 2       Travis Walters                   Java  Intermediate     12/09/2023
# 3     Nathaniel Harris        Web Development      Advanced     13/09/2023
# 5         Tonya Carter  AI & Machine Learning      Beginner     14/09/2023
# 6           Erik Smith     Mobile Development      Beginner     15/09/2023
# 7   Kristopher Johnson                 Python      Beginner     16/09/2023
# 9          Robert Buck                 PYTHON       Master      17/09/2023
# 10     Joseph Mcdonald                   Java  Intermediate     18/09/2023
# 11       Jerome Abbott        Web Development      Advanced     19/09/2023
# 12       William Riley  AI & Machine Learning      Beginner     20/09/2023

# %%
#problem 1 :inconsistency formatting in course and courselevel(some capitalized ,some are uppercase)

#to format string ,u can access str in pandas

df["Course"]=df['Course'].str.capitalize()
df["CourseLevel"]=df['CourseLevel'].str.capitalize()
df
# Out:
#                   Name                 Course   CourseLevel Formatted Date
# 0   Christy Cunningham                 Python      Beginner     10/09/2023
# 1       Douglas Tucker                 Python       Master      11/09/2023
# 2       Travis Walters                   Java  Intermediate     12/09/2023
# 3     Nathaniel Harris        Web development      Advanced     13/09/2023
# 5         Tonya Carter  Ai & machine learning      Beginner     14/09/2023
# 6           Erik Smith     Mobile development      Beginner     15/09/2023
# 7   Kristopher Johnson                 Python      Beginner     16/09/2023
# 9          Robert Buck                 Python       Master      17/09/2023
# 10     Joseph Mcdonald                   Java  Intermediate     18/09/2023
# 11       Jerome Abbott        Web development      Advanced     19/09/2023
# 12       William Riley  Ai & machine learning      Beginner     20/09/2023

# %% [markdown]
# ###4.Registering Fonts

# %%
font_path = '/content/drive/MyDrive/Colab Notebooks/Certificate Generator/fonts'

# %%
#registering 2 font into this project

#one of the command in pdfmetrics----->registerFont()
#TTfont() will need 2 input
#1st input---?what font?
#2nd input --->Where the folder located at


pdfmetrics.registerFont(TTFont('Lora Bold',font_path+'/Lora-Bold.ttf'))
pdfmetrics.registerFont(TTFont('Lora Regular',font_path+'/Lora-Regular.ttf'))

# %%
def certificate_generator(name,courseName,courselevel,date):

  #define the name of the new pdf that generated certificated

    pdf_file_name ='/content/drive/MyDrive/Colab Notebooks/Certificate_Generator/certificates/'+name+'-'+courseName+'-'+courselevel+'.pdf'

# %%
def certificate_generator(name,courseName,courselevel,date):

  #define the name of the new pdf that generated certificated

  pdf_file_name ='/content/drive/MyDrive/Colab Notebooks/Certificate Generator/certificates/'+name+'-'+courseName+'-'+courselevel+'.pdf'


  #canvas () will need 2 input
  #1s input  ---where you store
  #2nd input ---what size?

  c = canvas.Canvas(pdf_file_name, pagesize=landscape(A4))

  #adjust drawImage () need 5 inputs
  #1st input --->image --->template
  #2nd input ------>x axis (cordinate 0)
  #3rd input--------->yu axis (cordinate 0)(0,0)----place very top place corner
  #4th input----------->width A4[1]--------STANDARD
  #5TH Input--------------->Height--------A4[0]---------->Standard

  c.drawImage('/content/drive/MyDrive/Colab Notebooks/Certificate Generator/certificate_template.jpg',0,0,width=A4[1],height=A4[0])
  c.save()

# %%
certificate_generator('Abu','Phyton','Beginner','14/07/2024')

# %% [markdown]
# #Version 2 of function

# %%
def certificate_generator(name,courseName,courselevel,date):


  pdf_file_name ='/content/drive/MyDrive/Colab Notebooks/Certificate Generator/certificates/'+name+'-'+courseName+'-'+courselevel+'.pdf'


  c = canvas.Canvas(pdf_file_name, pagesize=landscape(A4))


  c.drawImage('/content/drive/MyDrive/Colab Notebooks/Certificate Generator/certificate_template.jpg',0,0,width=A4[1],height=A4[0])


  #let calculate center of landscape page

  print("'-------------------------------------------")

  center_x = c._pagesize[0]/2

  print('Full width of A4 ',c._pagesize[0])
  print('Center of the A4(x-axis):',center_x)



  center_y = c._pagesize[1]/2

  print('Full height of A4 ',c._pagesize[1])
  print('Center of the A4(y-axis):',center_y)

  c.save()

# %%
def certificate_generator(name,courseName,courselevel,date):


  pdf_file_name ='/content/drive/MyDrive/Colab Notebooks/Certificate Generator/certificates/'+name+'-'+courseName+'-'+courselevel+'.pdf'


  c = canvas.Canvas(pdf_file_name, pagesize=landscape(A4))


  c.drawImage('/content/drive/MyDrive/Colab Notebooks/Certificate Generator/certificate_template.jpg',0,0,width=A4[1],height=A4[0])

  center_x = c._pagesize[0]/2
  center_y = c._pagesize[1]/2


  #now that we got the centre of x * y

  #.setFont()--------------->needs 2 input

  #1st input------------>font type
  #2nd input ----->font size(px)

  #----------------------------------
  #.drawCentredString ----------->Need 3 input(X , Y , What you drawing on canvas)

  #Name
  c.setFont('Lora Bold',30)
  c.drawCentredString(center_x,center_y-46,name)

  #CourseLeve/Name
  c.setFont('Lora Regular',28)
  c.drawCentredString(center_x,center_y-105,courseName+'-'+courselevel)

  #Date
  c.setFont('Lora Bold',17)
  c.drawCentredString(center_x+ 190 ,center_y-160,date)

  #Cert_ID

  cert_id ='Cert ID:' + str(int(pd.Timestamp.now().timestamp()))
  c.setFont('Lora Regular',12)
  c.drawCentredString(center_x+ 266 ,center_y-230,cert_id.upper())

  c.save()

# %%
#For Cert ID , is has to be unique , we can uniquely generate id using timestamp


print(pd.Timestamp.now())
print(pd.Timestamp.now().timestamp())#unix timestampe(number of second from 1 january 1970)
print(int(pd.Timestamp.now().timestamp()))#remove floating points
# Out:
# 2024-07-21 04:21:49.851846
# 1721535709.853754
# 1721535709

# %%
certificate_generator('Abu','Phyton','Beginner','21/07/2024')

# %%
#for loop

#df.interrows give  u a loopable(array-like) and give 2 items(index,item(row))

for index,row in df.iterrows():
  certificate_generator(row['Name'],row['Course'],row['CourseLevel'],row['Formatted Date'])


print(str(len(df)) + 'certificates generated')
# Out:
# 11certificates generated

# %%
df.head()
# Out:
#                  Name                 Course   CourseLevel Formatted Date
# 0  Christy Cunningham                 Python      Beginner     10/09/2023
# 1      Douglas Tucker                 Python       Master      11/09/2023
# 2      Travis Walters                   Java  Intermediate     12/09/2023
# 3    Nathaniel Harris        Web development      Advanced     13/09/2023
# 5        Tonya Carter  Ai & machine learning      Beginner     14/09/2023
